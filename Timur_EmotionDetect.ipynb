# %%
import os
import time
from google.cloud import translate_v2 as translate
from tqdm import tqdm

BATCH_SIZE = 50
MAX_CHARS_PER_BATCH = 5000
SLEEP_BETWEEN_BATCHES = 1.5
TARGET_LANG = 'ky'

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/zinc-primer-459307-c4-e931e1449cd5.json"

translate_client = translate.Client()

def load_labeled_lines(path):
    lines = []
    with open(path, 'r', encoding='utf-8') as file:
        for line in file:
            if ";" in line:
                text, emotion = line.strip().split(";", 1)
                lines.append((text.strip(), emotion.strip()))
    return lines

def translate_batch(batch_texts, target=TARGET_LANG):
    if not batch_texts:
        return []
    try:
        return translate_client.translate(batch_texts, target_language=target)
    except Exception as e:
        print("❌ Ошибка при переводе:", e)
        return [{"translatedText": ""} for _ in batch_texts]

def save_translations(translated_pairs, output_path):
    with open(output_path, 'w', encoding='utf-8') as f:
        for text, emotion in translated_pairs:
            f.write(f"{text};{emotion}\n")

def process_file(input_path, output_path):
    print(f"\n📄 Обработка файла: {os.path.basename(input_path)}")
    lines = load_labeled_lines(input_path)
    total = len(lines)
    translated_data = []
    batch = []
    batch_emotions = []
    current_chars = 0
    translated_count = 0

    for i, (text, emotion) in enumerate(lines):
        if current_chars + len(text) > MAX_CHARS_PER_BATCH or len(batch) >= BATCH_SIZE:
            results = translate_batch(batch)
            translated_data.extend([
                (result['translatedText'], emo) for result, emo in zip(results, batch_emotions)
            ])
            translated_count += len(batch)
            print(f"✅ Переведено {translated_count} из {total} строк.")
            time.sleep(SLEEP_BETWEEN_BATCHES)
            batch = []
            batch_emotions = []
            current_chars = 0

        batch.append(text)
        batch_emotions.append(emotion)
        current_chars += len(text)

    if batch:
        results = translate_batch(batch)
        translated_data.extend([
            (result['translatedText'], emo) for result, emo in zip(results, batch_emotions)
        ])
        translated_count += len(batch)
        print(f"✅ Переведено {translated_count} из {total} строк (завершено).")

    save_translations(translated_data, output_path)
    print(f"💾 Сохранено: {len(translated_data)} строк → {output_path}")

input_folder = "/content/archive"
output_folder = "translated_kyrgyz"
os.makedirs(output_folder, exist_ok=True)

for fname in ["train.txt", "val.txt", "test.txt"]:
    process_file(
        input_path=os.path.join(input_folder, fname),
        output_path=os.path.join(output_folder, fname)
    )
# Out:
# 📄 Обработка файла: train.txt
# ✅ Переведено 50 из 16000 строк.
# ✅ Переведено 99 из 16000 строк.
# ✅ Переведено 140 из 16000 строк.
# ✅ Переведено 188 из 16000 строк.
# ✅ Переведено 237 из 16000 строк.
# ✅ Переведено 283 из 16000 строк.
# ✅ Переведено 333 из 16000 строк.
# ✅ Переведено 383 из 16000 строк.
# ✅ Переведено 433 из 16000 строк.
# ✅ Переведено 474 из 16000 строк.
# ✅ Переведено 524 из 16000 строк.
# ✅ Переведено 574 из 16000 строк.
# ✅ Переведено 624 из 16000 строк.
# ✅ Переведено 674 из 16000 строк.
# ✅ Переведено 724 из 16000 строк.
# ✅ Переведено 768 из 16000 строк.
# ✅ Переведено 815 из 16000 строк.
# ✅ Переведено 865 из 16000 строк.
# ✅ Переведено 915 из 16000 строк.
# ✅ Переведено 965 из 16000 строк.
# ✅ Переведено 1015 из 16000 строк.
# ✅ Переведено 1058 из 16000 строк.
# ✅ Переведено 1108 из 16000 строк.
# ✅ Переведено 1155 из 16000 строк.
# ✅ Переведено 1205 из 16000 строк.
# ✅ Переведено 1253 из 16000 строк.
# ✅ Переведено 1303 из 16000 строк.
# ✅ Переведено 1353 из 16000 строк.
# ✅ Переведено 1400 из 16000 строк.
# ✅ Переведено 1450 из 16000 строк.
# ✅ Переведено 1498 из 16000 строк.
# ✅ Переведено 1548 из 16000 строк.
# ✅ Переведено 1598 из 16000 строк.
# ✅ Переведено 1647 из 16000 строк.
# ✅ Переведено 1697 из 16000 строк.
# ✅ Переведено 1744 из 16000 строк.
# ✅ Переведено 1794 из 16000 строк.
# ✅ Переведено 1844 из 16000 строк.
# ✅ Переведено 1894 из 16000 строк.
# ✅ Переведено 1944 из 16000 строк.
# ✅ Переведено 1994 из 16000 строк.
# ✅ Переведено 2041 из 16000 строк.
# ✅ Переведено 2091 из 16000 строк.
# ✅ Переведено 2141 из 16000 строк.
# ✅ Переведено 2191 из 16000 строк.
# ✅ Переведено 2241 из 16000 строк.
# ✅ Переведено 2285 из 16000 строк.
# ✅ Переведено 2335 из 16000 строк.
# ✅ Переведено 2385 из 16000 строк.
# ✅ Переведено 2435 из 16000 строк.
# ✅ Переведено 2485 из 16000 строк.
# ✅ Переведено 2535 из 16000 строк.
# ✅ Переведено 2583 из 16000 строк.
# ✅ Переведено 2630 из 16000 строк.
# ✅ Переведено 2674 из 16000 строк.
# ✅ Переведено 2724 из 16000 строк.
# ✅ Переведено 2774 из 16000 строк.
# ✅ Переведено 2822 из 16000 строк.
# ✅ Переведено 2872 из 16000 строк.
# ✅ Переведено 2922 из 16000 строк.
# ✅ Переведено 2970 из 16000 строк.
# ✅ Переведено 3020 из 16000 строк.
# ✅ Переведено 3069 из 16000 строк.
# ✅ Переведено 3110 из 16000 строк.
# ✅ Переведено 3160 из 16000 строк.
# ✅ Переведено 3210 из 16000 строк.
# ✅ Переведено 3259 из 16000 строк.
# ✅ Переведено 3309 из 16000 строк.
# ✅ Переведено 3356 из 16000 строк.
# ✅ Переведено 3404 из 16000 строк.
# ✅ Переведено 3454 из 16000 строк.
# ✅ Переведено 3502 из 16000 строк.
# ✅ Переведено 3547 из 16000 строк.
# ✅ Переведено 3597 из 16000 строк.
# ✅ Переведено 3647 из 16000 строк.
# ✅ Переведено 3697 из 16000 строк.
# ✅ Переведено 3743 из 16000 строк.
# ✅ Переведено 3791 из 16000 строк.
# ✅ Переведено 3841 из 16000 строк.
# ✅ Переведено 3891 из 16000 строк.
# ✅ Переведено 3939 из 16000 строк.
# ✅ Переведено 3987 из 16000 строк.
# ✅ Переведено 4035 из 16000 строк.
# ✅ Переведено 4085 из 16000 строк.
# ✅ Переведено 4134 из 16000 строк.
# ✅ Переведено 4184 из 16000 строк.
# ✅ Переведено 4234 из 16000 строк.
# ✅ Переведено 4284 из 16000 строк.
# ✅ Переведено 4334 из 16000 строк.
# ✅ Переведено 4384 из 16000 строк.
# ✅ Переведено 4432 из 16000 строк.
# ✅ Переведено 4478 из 16000 строк.
# ✅ Переведено 4524 из 16000 строк.
# ✅ Переведено 4574 из 16000 строк.
# ✅ Переведено 4624 из 16000 строк.
# ✅ Переведено 4674 из 16000 строк.
# ✅ Переведено 4724 из 16000 строк.
# ✅ Переведено 4774 из 16000 строк.
# ✅ Переведено 4821 из 16000 строк.
# ✅ Переведено 4871 из 16000 строк.
# ✅ Переведено 4921 из 16000 строк.
# ✅ Переведено 4970 из 16000 строк.
# ✅ Переведено 5019 из 16000 строк.
# ✅ Переведено 5066 из 16000 строк.
# ✅ Переведено 5116 из 16000 строк.
# ✅ Переведено 5163 из 16000 строк.
# ✅ Переведено 5213 из 16000 строк.
# ✅ Переведено 5263 из 16000 строк.
# ✅ Переведено 5313 из 16000 строк.
# ✅ Переведено 5361 из 16000 строк.
# ✅ Переведено 5411 из 16000 строк.
# ✅ Переведено 5461 из 16000 строк.
# ✅ Переведено 5508 из 16000 строк.
# ✅ Переведено 5553 из 16000 строк.
# ✅ Переведено 5603 из 16000 строк.
# ✅ Переведено 5653 из 16000 строк.
# ✅ Переведено 5702 из 16000 строк.
# ✅ Переведено 5752 из 16000 строк.
# ✅ Переведено 5802 из 16000 строк.
# ✅ Переведено 5848 из 16000 строк.
# ✅ Переведено 5898 из 16000 строк.
# ✅ Переведено 5940 из 16000 строк.
# ✅ Переведено 5990 из 16000 строк.
# ✅ Переведено 6040 из 16000 строк.
# ✅ Переведено 6090 из 16000 строк.
# ✅ Переведено 6140 из 16000 строк.
# ✅ Переведено 6190 из 16000 строк.
# ✅ Переведено 6240 из 16000 строк.
# ✅ Переведено 6287 из 16000 строк.
# ✅ Переведено 6337 из 16000 строк.
# ✅ Переведено 6385 из 16000 строк.
# ✅ Переведено 6435 из 16000 строк.
# ✅ Переведено 6485 из 16000 строк.
# ✅ Переведено 6533 из 16000 строк.
# ✅ Переведено 6583 из 16000 строк.
# ✅ Переведено 6623 из 16000 строк.
# ✅ Переведено 6673 из 16000 строк.
# ✅ Переведено 6723 из 16000 строк.
# ✅ Переведено 6773 из 16000 строк.
# ✅ Переведено 6823 из 16000 строк.
# ✅ Переведено 6873 из 16000 строк.
# ✅ Переведено 6923 из 16000 строк.
# ✅ Переведено 6971 из 16000 строк.
# ✅ Переведено 7021 из 16000 строк.
# ✅ Переведено 7071 из 16000 строк.
# ✅ Переведено 7121 из 16000 строк.
# ✅ Переведено 7171 из 16000 строк.
# ✅ Переведено 7221 из 16000 строк.
# ✅ Переведено 7271 из 16000 строк.
# ✅ Переведено 7321 из 16000 строк.
# ✅ Переведено 7367 из 16000 строк.
# ✅ Переведено 7417 из 16000 строк.
# ✅ Переведено 7460 из 16000 строк.
# ✅ Переведено 7505 из 16000 строк.
# ✅ Переведено 7555 из 16000 строк.
# ✅ Переведено 7603 из 16000 строк.
# ✅ Переведено 7649 из 16000 строк.
# ✅ Переведено 7697 из 16000 строк.
# ✅ Переведено 7747 из 16000 строк.
# ✅ Переведено 7797 из 16000 строк.
# ✅ Переведено 7847 из 16000 строк.
# ✅ Переведено 7897 из 16000 строк.
# ✅ Переведено 7947 из 16000 строк.
# ✅ Переведено 7997 из 16000 строк.
# ✅ Переведено 8047 из 16000 строк.
# ✅ Переведено 8092 из 16000 строк.
# ✅ Переведено 8142 из 16000 строк.
# ✅ Переведено 8192 из 16000 строк.
# ✅ Переведено 8242 из 16000 строк.
# ✅ Переведено 8291 из 16000 строк.
# ✅ Переведено 8338 из 16000 строк.
# ✅ Переведено 8386 из 16000 строк.
# ✅ Переведено 8436 из 16000 строк.
# ✅ Переведено 8485 из 16000 строк.
# ✅ Переведено 8535 из 16000 строк.
# ✅ Переведено 8585 из 16000 строк.
# ✅ Переведено 8635 из 16000 строк.
# ✅ Переведено 8685 из 16000 строк.
# ✅ Переведено 8730 из 16000 строк.
# ✅ Переведено 8775 из 16000 строк.
# ✅ Переведено 8825 из 16000 строк.
# ✅ Переведено 8875 из 16000 строк.
# ✅ Переведено 8925 из 16000 строк.
# ✅ Переведено 8975 из 16000 строк.
# ✅ Переведено 9025 из 16000 строк.
# ✅ Переведено 9075 из 16000 строк.
# ✅ Переведено 9125 из 16000 строк.
# ✅ Переведено 9173 из 16000 строк.
# ✅ Переведено 9223 из 16000 строк.
# ✅ Переведено 9271 из 16000 строк.
# ✅ Переведено 9321 из 16000 строк.
# ✅ Переведено 9371 из 16000 строк.
# ✅ Переведено 9421 из 16000 строк.
# ✅ Переведено 9471 из 16000 строк.
# ✅ Переведено 9521 из 16000 строк.
# ✅ Переведено 9571 из 16000 строк.
# ✅ Переведено 9618 из 16000 строк.
# ✅ Переведено 9662 из 16000 строк.
# ✅ Переведено 9712 из 16000 строк.
# ✅ Переведено 9760 из 16000 строк.
# ✅ Переведено 9808 из 16000 строк.
# ✅ Переведено 9858 из 16000 строк.
# ✅ Переведено 9908 из 16000 строк.
# ✅ Переведено 9954 из 16000 строк.
# ✅ Переведено 10004 из 16000 строк.
# ✅ Переведено 10054 из 16000 строк.
# ✅ Переведено 10104 из 16000 строк.
# ✅ Переведено 10151 из 16000 строк.
# ✅ Переведено 10201 из 16000 строк.
# ✅ Переведено 10251 из 16000 строк.
# ✅ Переведено 10301 из 16000 строк.
# ✅ Переведено 10350 из 16000 строк.
# ✅ Переведено 10389 из 16000 строк.
# ✅ Переведено 10439 из 16000 строк.
# ✅ Переведено 10488 из 16000 строк.
# ✅ Переведено 10536 из 16000 строк.
# ✅ Переведено 10586 из 16000 строк.
# ✅ Переведено 10636 из 16000 строк.
# ✅ Переведено 10686 из 16000 строк.
# ✅ Переведено 10736 из 16000 строк.
# ✅ Переведено 10786 из 16000 строк.
# ✅ Переведено 10836 из 16000 строк.
# ✅ Переведено 10886 из 16000 строк.
# ✅ Переведено 10936 из 16000 строк.
# ✅ Переведено 10986 из 16000 строк.
# ✅ Переведено 11036 из 16000 строк.
# ✅ Переведено 11086 из 16000 строк.
# ✅ Переведено 11134 из 16000 строк.
# ✅ Переведено 11184 из 16000 строк.
# ✅ Переведено 11231 из 16000 строк.
# ✅ Переведено 11275 из 16000 строк.
# ✅ Переведено 11325 из 16000 строк.
# ✅ Переведено 11369 из 16000 строк.
# ✅ Переведено 11416 из 16000 строк.
# ✅ Переведено 11466 из 16000 строк.
# ✅ Переведено 11516 из 16000 строк.
# ✅ Переведено 11566 из 16000 строк.
# ✅ Переведено 11611 из 16000 строк.
# ✅ Переведено 11659 из 16000 строк.
# ✅ Переведено 11709 из 16000 строк.
# ✅ Переведено 11757 из 16000 строк.
# ✅ Переведено 11807 из 16000 строк.
# ✅ Переведено 11856 из 16000 строк.
# ✅ Переведено 11906 из 16000 строк.
# ✅ Переведено 11956 из 16000 строк.
# ✅ Переведено 12006 из 16000 строк.
# ✅ Переведено 12056 из 16000 строк.
# ✅ Переведено 12106 из 16000 строк.
# ✅ Переведено 12156 из 16000 строк.
# ✅ Переведено 12206 из 16000 строк.
# ✅ Переведено 12256 из 16000 строк.
# ✅ Переведено 12306 из 16000 строк.
# ✅ Переведено 12356 из 16000 строк.
# ✅ Переведено 12406 из 16000 строк.
# ✅ Переведено 12456 из 16000 строк.
# ✅ Переведено 12506 из 16000 строк.
# ✅ Переведено 12553 из 16000 строк.
# ✅ Переведено 12597 из 16000 строк.
# ✅ Переведено 12647 из 16000 строк.
# ✅ Переведено 12697 из 16000 строк.
# ✅ Переведено 12747 из 16000 строк.
# ✅ Переведено 12796 из 16000 строк.
# ✅ Переведено 12845 из 16000 строк.
# ✅ Переведено 12895 из 16000 строк.
# ✅ Переведено 12942 из 16000 строк.
# ✅ Переведено 12992 из 16000 строк.
# ✅ Переведено 13036 из 16000 строк.
# ✅ Переведено 13086 из 16000 строк.
# ✅ Переведено 13136 из 16000 строк.
# ✅ Переведено 13186 из 16000 строк.
# ✅ Переведено 13233 из 16000 строк.
# ✅ Переведено 13283 из 16000 строк.
# ✅ Переведено 13333 из 16000 строк.
# ✅ Переведено 13383 из 16000 строк.
# ✅ Переведено 13433 из 16000 строк.
# ✅ Переведено 13480 из 16000 строк.
# ✅ Переведено 13530 из 16000 строк.
# ✅ Переведено 13580 из 16000 строк.
# ✅ Переведено 13630 из 16000 строк.
# ✅ Переведено 13680 из 16000 строк.
# ✅ Переведено 13724 из 16000 строк.
# ✅ Переведено 13773 из 16000 строк.
# ✅ Переведено 13823 из 16000 строк.
# ✅ Переведено 13873 из 16000 строк.
# ✅ Переведено 13923 из 16000 строк.
# ✅ Переведено 13973 из 16000 строк.
# ✅ Переведено 14018 из 16000 строк.
# ✅ Переведено 14067 из 16000 строк.
# ✅ Переведено 14117 из 16000 строк.
# ✅ Переведено 14167 из 16000 строк.
# ✅ Переведено 14217 из 16000 строк.
# ✅ Переведено 14267 из 16000 строк.
# ✅ Переведено 14315 из 16000 строк.
# ✅ Переведено 14365 из 16000 строк.
# ✅ Переведено 14413 из 16000 строк.
# ✅ Переведено 14463 из 16000 строк.
# ✅ Переведено 14513 из 16000 строк.
# ✅ Переведено 14563 из 16000 строк.
# ✅ Переведено 14613 из 16000 строк.
# ✅ Переведено 14663 из 16000 строк.
# ✅ Переведено 14713 из 16000 строк.
# ✅ Переведено 14763 из 16000 строк.
# ✅ Переведено 14810 из 16000 строк.
# ✅ Переведено 14859 из 16000 строк.
# ✅ Переведено 14909 из 16000 строк.
# ✅ Переведено 14959 из 16000 строк.
# ✅ Переведено 15009 из 16000 строк.
# ✅ Переведено 15058 из 16000 строк.
# ✅ Переведено 15108 из 16000 строк.
# ✅ Переведено 15154 из 16000 строк.
# ✅ Переведено 15201 из 16000 строк.
# ✅ Переведено 15251 из 16000 строк.
# ✅ Переведено 15301 из 16000 строк.
# ✅ Переведено 15347 из 16000 строк.
# ✅ Переведено 15397 из 16000 строк.
# ✅ Переведено 15446 из 16000 строк.
# ✅ Переведено 15496 из 16000 строк.
# ✅ Переведено 15544 из 16000 строк.
# ✅ Переведено 15594 из 16000 строк.
# ✅ Переведено 15644 из 16000 строк.
# ✅ Переведено 15694 из 16000 строк.
# ✅ Переведено 15744 из 16000 строк.
# ✅ Переведено 15789 из 16000 строк.
# ✅ Переведено 15831 из 16000 строк.
# ✅ Переведено 15881 из 16000 строк.
# ✅ Переведено 15931 из 16000 строк.
# ✅ Переведено 15981 из 16000 строк.
# ✅ Переведено 16000 из 16000 строк (завершено).
# 💾 Сохранено: 16000 строк → translated_kyrgyz/train.txt
#
# 📄 Обработка файла: val.txt
# ✅ Переведено 50 из 2000 строк.
# ✅ Переведено 100 из 2000 строк.
# ✅ Переведено 150 из 2000 строк.
# ✅ Переведено 200 из 2000 строк.
# ✅ Переведено 248 из 2000 строк.
# ✅ Переведено 295 из 2000 строк.
# ✅ Переведено 345 из 2000 строк.
# ✅ Переведено 395 из 2000 строк.
# ✅ Переведено 445 из 2000 строк.
# ✅ Переведено 495 из 2000 строк.
# ✅ Переведено 544 из 2000 строк.
# ✅ Переведено 594 из 2000 строк.
# ✅ Переведено 644 из 2000 строк.
# ✅ Переведено 694 из 2000 строк.
# ✅ Переведено 744 из 2000 строк.
# ✅ Переведено 794 из 2000 строк.
# ✅ Переведено 844 из 2000 строк.
# ✅ Переведено 894 из 2000 строк.
# ✅ Переведено 938 из 2000 строк.
# ✅ Переведено 988 из 2000 строк.
# ✅ Переведено 1038 из 2000 строк.
# ✅ Переведено 1088 из 2000 строк.
# ✅ Переведено 1138 из 2000 строк.
# ✅ Переведено 1188 из 2000 строк.
# ✅ Переведено 1238 из 2000 строк.
# ✅ Переведено 1288 из 2000 строк.
# ✅ Переведено 1336 из 2000 строк.
# ✅ Переведено 1386 из 2000 строк.
# ✅ Переведено 1436 из 2000 строк.
# ✅ Переведено 1486 из 2000 строк.
# ✅ Переведено 1535 из 2000 строк.
# ✅ Переведено 1582 из 2000 строк.
# ✅ Переведено 1632 из 2000 строк.
# ✅ Переведено 1682 из 2000 строк.
# ✅ Переведено 1728 из 2000 строк.
# ✅ Переведено 1778 из 2000 строк.
# ✅ Переведено 1823 из 2000 строк.
# ✅ Переведено 1870 из 2000 строк.
# ✅ Переведено 1920 из 2000 строк.
# ✅ Переведено 1970 из 2000 строк.
# ✅ Переведено 2000 из 2000 строк (завершено).
# 💾 Сохранено: 2000 строк → translated_kyrgyz/val.txt
#
# 📄 Обработка файла: test.txt
# ✅ Переведено 50 из 2000 строк.
# ✅ Переведено 100 из 2000 строк.
# ✅ Переведено 149 из 2000 строк.
# ✅ Переведено 199 из 2000 строк.
# ✅ Переведено 249 из 2000 строк.
# ✅ Переведено 299 из 2000 строк.
# ✅ Переведено 349 из 2000 строк.
# ✅ Переведено 399 из 2000 строк.
# ✅ Переведено 442 из 2000 строк.
# ✅ Переведено 489 из 2000 строк.
# ✅ Переведено 539 из 2000 строк.
# ✅ Переведено 589 из 2000 строк.
# ✅ Переведено 638 из 2000 строк.
# ✅ Переведено 688 из 2000 строк.
# ✅ Переведено 734 из 2000 строк.
# ✅ Переведено 784 из 2000 строк.
# ✅ Переведено 829 из 2000 строк.
# ✅ Переведено 879 из 2000 строк.
# ✅ Переведено 929 из 2000 строк.
# ✅ Переведено 976 из 2000 строк.
# ✅ Переведено 1026 из 2000 строк.
# ✅ Переведено 1075 из 2000 строк.
# ✅ Переведено 1125 из 2000 строк.
# ✅ Переведено 1174 из 2000 строк.
# ✅ Переведено 1217 из 2000 строк.
# ✅ Переведено 1266 из 2000 строк.
# ✅ Переведено 1316 из 2000 строк.
# ✅ Переведено 1364 из 2000 строк.
# ✅ Переведено 1414 из 2000 строк.
# ✅ Переведено 1464 из 2000 строк.
# ✅ Переведено 1513 из 2000 строк.
# ✅ Переведено 1563 из 2000 строк.
# ✅ Переведено 1609 из 2000 строк.
# ✅ Переведено 1659 из 2000 строк.
# ✅ Переведено 1706 из 2000 строк.
# ✅ Переведено 1756 из 2000 строк.
# ✅ Переведено 1806 из 2000 строк.
# ✅ Переведено 1856 из 2000 строк.
# ✅ Переведено 1906 из 2000 строк.
# ✅ Переведено 1956 из 2000 строк.
# ✅ Переведено 2000 из 2000 строк (завершено).
# 💾 Сохранено: 2000 строк → translated_kyrgyz/test.txt

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.14.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.2)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.31.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
# !pip install numpy==1.26.4 --quiet
import os
os._exit(0)

# %%
import os
import torch
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import evaluate
from sklearn.preprocessing import LabelEncoder
import pandas as pd

MODEL_NAME = "bert-base-multilingual-cased"
MAX_LENGTH = 128
BATCH_SIZE = 16
NUM_EPOCHS = 4
OUTPUT_DIR = "./kyrgyz-emotion-model"
VALID_LABELS = {'sadness', 'joy', 'fear', 'anger', 'love', 'surprise'}


def load_data(file_path, valid_labels):
    texts, labels = [], []
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            parts = line.strip().split(";", 1)
            if len(parts) != 2:
                print(f"⚠️ Пропущена некорректная строка {i + 1}: {line.strip()}")
                continue
            text, label = parts
            text, label = text.strip(), label.strip()
            if text:
                if label not in valid_labels:
                    label = "other"
                texts.append(text)
                labels.append(label)
    return pd.DataFrame({'text': texts, 'label': labels})

def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length=MAX_LENGTH)

train_df = load_data("train.txt", VALID_LABELS)
val_df = load_data("val.txt", VALID_LABELS)
test_df = load_data("test.txt", VALID_LABELS)

print("🔎 Уникальные метки в train.txt:", train_df['label'].unique())
print("🔎 Уникальные метки в val.txt:", val_df['label'].unique())
print("🔎 Уникальные метки в test.txt:", test_df['label'].unique())

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
val_df["label"] = label_encoder.transform(val_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

id2label = {i: label for i, label in enumerate(label_encoder.classes_)}
label2id = {label: i for i, label in id2label.items()}

train_ds = Dataset.from_pandas(train_df)
val_ds = Dataset.from_pandas(val_df)
test_ds = Dataset.from_pandas(test_df)

tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)
train_ds = train_ds.map(tokenize_function, batched=True)
val_ds = val_ds.map(tokenize_function, batched=True)
test_ds = test_ds.map(tokenize_function, batched=True)

train_ds.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
val_ds.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_ds.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

model = BertForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=len(label_encoder.classes_),
    id2label=id2label,
    label2id=label2id
)

accuracy = evaluate.load("accuracy")

def compute_metrics(p):
    preds = p.predictions.argmax(axis=1)
    return accuracy.compute(predictions=preds, references=p.label_ids)

training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()

print("Обучение завершено. Сохраняем модель...")
model.save_pretrained(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)

print("Тестирование:")
metrics = trainer.evaluate(test_ds)
print(metrics)
# Out:
# 🔎 Уникальные метки в train.txt: ['sadness' 'anger' 'love' 'surprise' 'fear' 'joy' 'other']
# 🔎 Уникальные метки в val.txt: ['sadness' 'love' 'anger' 'joy' 'fear' 'other' 'surprise']
# 🔎 Уникальные метки в test.txt: ['sadness' 'joy' 'fear' 'anger' 'love' 'surprise' 'other']
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Map:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-1-04115543c16c>:92: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: zhumataevtimurr (zhumataevtimurr-google) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250515_051328-9gwlsdal</code>
# Syncing run <strong><a href='https://wandb.ai/zhumataevtimurr-google/huggingface/runs/9gwlsdal' target="_blank">./kyrgyz-emotion-model</a></strong> to <a href='https://wandb.ai/zhumataevtimurr-google/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/zhumataevtimurr-google/huggingface' target="_blank">https://wandb.ai/zhumataevtimurr-google/huggingface</a>
#  View run at <a href='https://wandb.ai/zhumataevtimurr-google/huggingface/runs/9gwlsdal' target="_blank">https://wandb.ai/zhumataevtimurr-google/huggingface/runs/9gwlsdal</a>
#     <div>
#
#       <progress value='4000' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4000/4000 29:43, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.028500</td>
#       <td>0.826791</td>
#       <td>0.724500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.730900</td>
#       <td>0.714552</td>
#       <td>0.763000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.593700</td>
#       <td>0.681712</td>
#       <td>0.772500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.480600</td>
#       <td>0.712057</td>
#       <td>0.782500</td>
#     </tr>
#   </tbody>
# </table><p>
# Обучение завершено. Сохраняем модель...
# Тестирование:
#     <div>
#
#       <progress value='125' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [125/125 00:14]
#     </div>
# {'eval_loss': 0.7296693921089172, 'eval_accuracy': 0.7545, 'eval_runtime': 14.9058, 'eval_samples_per_second': 134.176, 'eval_steps_per_second': 8.386, 'epoch': 4.0}

# %%
def predict(texts):
    if isinstance(texts, str):
        texts = [texts]

    inputs = tokenizer(texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        preds = torch.argmax(probs, dim=-1).cpu().numpy()
    labels = [id2label[p] for p in preds]
    return labels, probs.cpu().numpy()

# %%
texts = [
    "Бакыт каалайбыз,кыргыздын көп жигиттери даай албай турган арстан жүрөктүү кыз,күйөө бала азамат"
]

labels, probabilities = predict(texts)

for text, label, probs in zip(texts, labels, probabilities):
    print(f"📝 Текст: {text}")
    print(f"🔮 Предсказание: {label}")
    for i, prob in enumerate(probs):
        print(f"   {id2label[i]}: {prob:.4f}")
    print("-" * 50)

for text, label in zip(texts, labels):
    print(f"📝 Текст: {text}\n🔮 Предсказание: {label}\n")
# Out:
# 📝 Текст: Бакыт каалайбыз,кыргыздын көп жигиттери даай албай турган арстан жүрөктүү кыз,күйөө бала азамат
# 🔮 Предсказание: joy
#    anger: 0.0032
#    fear: 0.0014
#    joy: 0.9534
#    love: 0.0362
#    other: 0.0004
#    sadness: 0.0040
#    surprise: 0.0013
# --------------------------------------------------
# 📝 Текст: Бакыт каалайбыз,кыргыздын көп жигиттери даай албай турган арстан жүрөктүү кыз,күйөө бала азамат
# 🔮 Предсказание: joy

# %%
train_df.head()
# Out:
#                                                 text  label
# 0                    өзүмдү кемсинткен сезген жокмун      5
# 1  Мен кам көргөн жана сергек адамдын жанында бол...      5
# 2  Мен пост жазууга бир мүнөт убакыт бөлүп жатам,...      0
# 3  Мен каминге болгон ностальгиялык сезимде болом...      3
# 4                       мен өзүмдү жаман сезип жатам      0
